# %%
num = [1,2,3,4,5]

print(num)
# Out:
# [1, 2, 3, 4, 5]

# %%
fruits = ['apple', 'mango', 'banana']
print(fruits)
# Out:
# ['apple', 'mango', 'banana']

# %%
mixed_list = [1, 3.4, 'mango', [1,2,3], True, False]
print(mixed_list)
# Out:
# [1, 3.4, 'mango', [1, 2, 3], True, False]

# %%
mixed_list[3][1]
# Out:
# 2

# %%
mixed_list[3][::-1]
# Out:
# [3, 2, 1]

# %%
mixed_list[-2]
# Out:
# True

# %%
num[-3::-1]
# Out:
# [3, 2, 1]

# %%
num[::-1] #num[1-:-6:-1]
# Out:
# [5, 4, 3, 2, 1]
