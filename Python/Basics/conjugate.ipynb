# %%
x=complex(4,5)
y=complex(5,6)

print(x)
print(y)
print(x.imag)
print(x.conjugate)
# Out:
# (4+5j)
# (5+6j)
# 5.0
# <built-in method conjugate of complex object at 0x000002088CC1BBD0>

# %%
# Define a complex number
z = 5 + 3j

# Get its conjugate
conjugate_z = z.conjugate()

# Print the result
print("Original:", z)
print("Conjugate:", conjugate_z)
# Out:
# Original: (5+3j)
# Conjugate: (5-3j)
