# %%
if 5 > 2:
    print('True')
# Out:
# True

# %%
age = int(input('Enter your age:'))

liecnce == True

if age >= 18 and license:  #relational operator
    print('Eligible to Drive')
# Out:
# Enter your age: 50
# Eligible to Drive

# %%
marks = int(input('Enter your marks:'))

if marks >= 101:
    print('Invalid marks')
elif marks > 90 and marks <= 100:
    print('Grade A')
elif marks > 80 and marks <= 90:
    print('Grade B')
elif marks > 70 and marks <= 80:
    print('Grade C')
elif marks > 60 and marks <= 70:
    print('Grade D')
else:
    print('Fail')
# Out:
# Enter your marks: 500
# Invalid marks

# %%
num = int(input('Enter a number:'))

if num > 0:
    print('Number is positive number')
elif num == 0:
    print('Number is either posotive nor negative')
else:
    print('Number is negative number')
# Out:
# Enter a number: -5
# Number is negative number

# %%
age = int(input("Enter your age:"))

if age >= 18:
    if license == True:
        print('Eligible to drive')
    else:
        print('Not eligible to drive')
else:
        print('Not eligible to drive')
# Out:
# Enter your age: 2
# Not eligible to drive

# %%
age = int(input("Enter your age:"))

id_ = input('Do you have voter id?').lower()

if age >= 18:
    if id_ == 'yes':
        print('Eligible for vote')
    else:
        print('Not eligible for vote')
else:
    print('Not eligible for vote')
# Out:
# Enter your age: 20
# Do you have voter id? no
# Not eligible for vote

# %%
#Voting system

age = int(input("Enter your age:"))

if age >= 18:
    id_ = input('Do you have voter id?').lower()
    if id_ == 'yes':
        print('Eligible for vote')
    else:
        print('Not eligible for vote')
else:
    print('Not eligible for vote')
# Out:
# Enter your age: 20
# Do you have voter id? yes
# Eligible for vote

# %%
num = int(input('Enter a number:'))

if num % 2 == 0:
    print('Your number is even number')
else:
    print('Your number is odd number')
# Out:
# Enter a number: 5
# Your number is odd number

# %%
a, b = 10, 15

#short-hand if statement
if a < b: print('a is smaller')
# Out:
# a is smaller

# %%
a = int(input('Enter a number'))
b = int(input('Enter a number'))

#short-hand if else statement

print('a is smaller than b') if a < b else print('b is smaller than a')
# Out:
# Enter a number 20
# Enter a number 30
# a is smaller than b

# %%
age = int(input('Enter your age:'))

liecnce == False

if age >= 18 or license:  #relational operator
    print('Eligible for Drive')
else:
    print('Not eligible for Drive')
# Out:
# Enter your age: 10
# Eligible for Drive

# %%
age = int(input('Enter your age:'))

liecnce == False

if age >= 18 and age <= 99 and license:  #relational operator
    print('Eligible for Drive')
else:
    print('Not eligible for Drive')
# Out:
# Enter your age: 50
# Eligible for Drive

# %%
age = int(input('Enter your age:'))

liecnce == False

if age >= 18 or license:  #relational operator
    pass
# Out:
# Enter your age: 50

# %%
year = int(input('Enter a year'))

if year % 4 == 0 or year % 100 == 0 and year % 400 == 0:
        print(year, 'is a leap year')
else:
    print(year, 'is not a leap year')
# Out:
# Enter a year 1996
# 1996 is a leap year
