# %%
#Euqal to
a=5

# %%
#addition equal to

a+=5      #a= a+5
print(a)
# Out:
# 10

# %%
#Substraction equal to

a -= 5
print(a)
# Out:
# 5

# %%
#Multiplication equal to

a *= 5
print(a)
# Out:
# 25

# %%
#Division equal to

a /= 5
print(a)
# Out:
# 5.0

# %%
#Floor division equal to

a //= 5 #a= a//5
print(a)
# Out:
# 1.0

# %%
#Modulus equal to

a%=5
print(a)
# Out:
# 1.0

# %%
#Power equal to

a**=5 #a= a*5
print(a)
# Out:
# 1.0

# %%
#Real Example

score =  0
score += 6
score += 6

print('Rohit Sharma score:', score)
# Out:
# Rohit Sharma score: 12
