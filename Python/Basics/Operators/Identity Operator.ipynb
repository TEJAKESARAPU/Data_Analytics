# %%
# Identity Operator

a = [1,2,3]
b = [1,2,3]
c = a

# %%
a is b
# Out:
# False

# %%
a==b
# Out:
# True

# %%
a is not b
# Out:
# True

# %%
a is c
# Out:
# True

# %%
b is a
# Out:
# False

# %%
b is not a
# Out:
# True

# %%
c is not a
# Out:
# False

# %%
c is a
# Out:
# True
