# %%
#Logical Operator

a,b,c = 6,8,9

# %%
a<b and c>b
# Out:
# True

# %%
a<b or b>c
# Out:
# True

# %%
not b>c
# Out:
# True

# %%
#Real life example

age = int(input('Enter your age:'))
license = True
if age >= 18 and license:
    print('Can drive')
else:
    print("Can't drive")
# Out:
# Enter your age: 20
# Can drive
