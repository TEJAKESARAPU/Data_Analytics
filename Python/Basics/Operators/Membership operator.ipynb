# %%
a = 'ram'

# %%
'r' in a
# Out:
# True

# %%
'c' in a
# Out:
# False

# %%
'r' not in a
# Out:
# False

# %%
# Real life example

fruits = ['apple', 'banana', 'grapes']

if 'banana' in fruits:
    print('Yes! banana is there in the bucket')
else:
    print('Banana is not there in the bucket')
# Out:
# Yes! banana is there in the bucket

# %%
name = 'rajamohan'

# %%
'mohan' in name
# Out:
# True
