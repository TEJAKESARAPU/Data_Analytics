# %%
5 & 2
# Out:
# 0

# %%
5 | 2
# Out:
# 7

# %%
5^2
# Out:
# 7

# %%
~5
# Out:
# -6

# %%
5>>2
# Out:
# 1

# %%
5<<2
# Out:
# 20

# %%
amount = int(input('Amount in your account'))
withdraw = int(input('Enter your withdraw amount'))

if withdraw > 0 and amount > withdraw:
    print('Transaction approved')
else:
    print('Insufficient balance')
# Out:
# Amount in your account 2000
# Enter your withdraw amount 100
# Transaction approved

# %%
#Convert minutes into hours

time = int(input('Enter time'))
hour = 60
minute = 60

print(time // hour, 'hour', 'and', time % minute, 'minutes')
# Out:
# Enter time 20
# 0 hour and 20 minutes
