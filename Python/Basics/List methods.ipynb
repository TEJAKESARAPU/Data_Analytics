# %%
fruits = ['apple', 'banana', 'mango']

# %%
#Append method

fruits.append('kiwi')

# %%
fruits
# Out:
# ['apple', 'mango', 'banana', 'kiwi']

# %%
fruits.sort()

# %%
fruits
# Out:
# ['apple', 'banana', 'kiwi', 'mango']

# %%
fruits.insert(1,'grapes')

# %%
fruits
# Out:
# ['apple', 'grapes', 'banana', 'kiwi', 'mango']

# %%
fruits.index('mango')
# Out:
# 4

# %%
fruits.pop()
fruits
# Out:
# ['apple', 'grapes', 'banana', 'kiwi']

# %%
fruits.remove('kiwi')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 fruits.remove('kiwi')
#
# ValueError: list.remove(x): x not in list

# %%
fruits
# Out:
# ['apple', 'grapes', 'banana']

# %%
len(fruits)
# Out:
# 3

# %%
fruits.clear()

# %%
fruits
# Out:
# []

# %%
fruits = ['apple', 'banana', 'mango']
fruits.reverse()

# %%
fruits
# Out:
# ['mango', 'banana', 'apple']

# %%
id(fruits)
# Out:
# 1770572944192
