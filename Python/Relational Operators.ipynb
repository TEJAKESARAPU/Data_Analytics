# %%
#Relational Operators

a=20
b=30

print('a is equal to b:',a==b)
print('a is not equal to b:',a!=b)
print('a is greather than b:',a>b)
print('a is less than b:',a<b)
print('a is greather than equal to b:',a>=b)
print('a is less than equal to b:',a<=b)
# Out:
# a is equal to b: False
# a is not equal to b: True
# a is greather than b: False
# a is less than b: True
# a is greather than equal to b: False
# a is less than equal to b: True

# %%
a = 'p'
b = 'P'

print(ord('p'))
print(ord('P'))

print('a is equal to b:',a==b)
print('a is not equal to b:',a!=b)
print('a is greather than b:',a>b)
print('a is less than b:',a<b)
print('a is greather than equal to b:',a>=b)
print('a is less than equal to b:',a<=b)
# Out:
# 112
# 80
# a is equal to b: False
# a is not equal to b: True
# a is greather than b: True
# a is less than b: False
# a is greather than equal to b: True
# a is less than equal to b: False

# %%
ord('=')
# Out:
# 61

# %%
chr(80)
# Out:
# 'P'

# %%
a,b = True, False

print('a is equal to b:',a==b)
print('a is not equal to b:',a!=b)
print('a is greather than b:',a>b)
print('a is less than b:',a<b)
print('a is greather than equal to b:',a>=b)
print('a is less than equal to b:',a<=b)
# Out:
# a is equal to b: False
# a is not equal to b: True
# a is greather than b: True
# a is less than b: False
# a is greather than equal to b: True
# a is less than equal to b: False

# %%
dir(bool)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
# ...

# %%
#how to check keyword

import keyword as k
keywords = k.kwlist

# %%
len(keywords)
# Out:
# 35

# %%
F = int(input('Enter temperature in Farenhaite:'))
C = (F-32) * 5/9

print('Temperature in Celcius:', C)
# Out:
# Enter temperature in Farenhaite: 98
# Temperature in Celcius: 36.666666666666664

# %%
age=int(input('Enter your age:'))

if age >= 18:
    print('He/She can cast Vote')
else:
    print('They cannot cast vote')
# Out:
# Enter your age: 11
# They cannot cast vote
